# %%
class Camera:
    def __init__(self, nome:str=None, filmando:str=False):
        self.nome = nome
        self.filmando = filmando

    def filmar(self):
        if self.filmando:
            return f'A {self.nome} ja está filmando'
        else:
            self.filmando = True 
            return f'A {self.nome} comecou a filmar'
    
    def fotografar(self):
        if self.filmando:
            return f'A {self.nome} nao pode fotografar com ela filmando, pare a filmagem'
        
        else:
            return f'A {self.nome} tirou uma foto'

    def parar(self):
        if not self.filmando:
            return f'A {self.nome} ja parou de filmar'
        self.filmando = False
        return 'Parando de filmar em 3,2,1...'
    
    
class Camera:
    def __init__(self, nome, filmando=False):
        self.nome = nome
        self.filmando = filmando

    def filmar(self):
        if self.filmando:
            print(f'{self.nome} JÁ está filmando...')
            return

        print(f'{self.nome} está filmando...')
        self.filmando = True

    def parar_filmar(self):
        if not self.filmando:
            print(f'{self.nome} NÃO está filmando...')
            return

        print(f'{self.nome} está parando de filmar...')
        self.filmando = False

    def fotografar(self):
        if self.filmando:
            print(f'{self.nome} não pode fotografar filmando')
            return

        print(f'{self.nome} está fotografando...')

# %%
cano = Camera('Canon')

# %%
cano.fotografar()
# Out:
# 'A Canon nao pode fotografar com ela filmando, pare a filmagem'

# %%
class Pessoa:
    nome_asidof = 2302
    
    def __init__(self,nome:str=None):
        self.nome = nome 
        
    def prisdf(self):
        print(self.nome_asidof)
        print(Pessoa.nome_asidof)

# %%
Pessoa.nome_asidof
# Out:
# 2302

# %%
Pessoa().prisdf()
# Out:
# 2302
# 2302

# %%
import os
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\diegonca\\AppData\\Roaming',
#         'APPLICATIONINSIGHTS_CONFIGURATION_CONTENT': '{}',
#         'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_18584_TEZSVRJTXDMEKSHW',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'LBR-PE04YPN9',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_7892': '1',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'GPPT_CACHEFOLDER': 'C:\\Windows\\ccmcache',
#         'GPPT_INSTALLFOLDER': 'c:\\Installers',
# ...

# %%
test_list = [{'gfg' : 1, 'is' : 2, 'good' : 3}, 
             {'gfg' : 2}, {'best' : 3, 'gfg' : 4}]
  
# printing original list
print("The original list is : " + str(test_list))
print("The original list is : ",myList)
# Out:
# The original list is : [{'gfg': 1, 'is': 2, 'good': 3}, {'gfg': 2}, {'best': 3, 'gfg': 4}]
# The original list is :  [{'foo': 12, 'bar': 14}, {'moo': 52, 'car': 641}, {'doo': 6, 'tar': 84}]

# %%
myList = [
	{
		'foo':12,
		'bar':14
	},
	{
		'moo':52,
		'car':641
	},
	{
		'doo':6,
		'tar':84
	}
]

# %%
import os
#os.environ

# %%
res = [ sub["gfg"] for sub in test_list ]

# %%
test_list[0]
# Out:
# 1

# %%
import os

# %%
type(os)
# Out:
# module

# %%
type(os.environ)
# Out:
# os._Environ

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
# ...

# %%
type(os.environ)
# Out:
# os._Environ

# %%
spark.table()
