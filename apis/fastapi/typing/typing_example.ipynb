# %%
from typing import Optional

def greet(name: Optional[str] = None) -> str:
    if name is None:
        return "Hello, world!"
    else:
        return f"Hello, {name}!"

# %%
greet(1)

# %%
def greet2(name: str = None) -> str:
    if name is None:
        return "Hello, world!"
    else:
        return f"Hello, {name}!"

# %%
greet2(1)
