# %%
import gspread
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials
from datetime import date, datetime, timedelta
import re

# %%
# define the scope
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# add credentials to the account
creds = ServiceAccountCredentials.from_json_keyfile_name('./json/pass.json', scope)

# authorize the clientsheet
client = gspread.authorize(creds)

# %%
gc = gspread.service_account()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gc = gspread.service_account()
#
# File /opt/conda/lib/python3.11/site-packages/gspread/auth.py:324, in service_account(filename, scopes, http_client)
#     295 def service_account(
#     296     filename: Union[Path, str] = DEFAULT_SERVICE_ACCOUNT_FILENAME,
#     297     scopes: Iterable[str] = DEFAULT_SCOPES,
#     298     http_client: HTTPClientType = HTTPClient,
#     299 ) -> Client:
#     300     """Authenticate using a service account.
#     301
#     302     ``scopes`` parameter defaults to read/write scope available in
#    (...)
#     322     :rtype: :class:`gspread.client.Client`
#     323     """
# --> 324     creds = SACredentials.from_service_account_file(filename, scopes=scopes)
#     325     return Client(auth=creds, http_client=http_client)
#
# ...

# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 49.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 52.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.1/229.1 kB 44.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 19.6 MB/s eta 0:00:00
# ...

# %%
# !touch ~/.config/gspread/credentials.json
# Out:
# touch: cannot touch '/home/jovyan/.config/gspread/credentials.json': No such file or directory

# %%
from google.oauth2.service_account import Credentials, ServiceAccountCredentials

scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]

credentials = Credentials.from_service_account_file(
    './work/pythonclub/credential.json',
    scopes=scopes
)

gc = gspread.authorize(credentials)

# %%
Credentials.from

# %%
gc

# %%
gc.open('minhas_contas')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/gspread/client.py:132, in Client.open(self, title, folder_id)
#     131 try:
# --> 132     properties = finditem(
#     133         lambda x: x["name"] == title,
#     134         spreadsheet_files,
#     135     )
#     136 except StopIteration as ex:
#
# File /opt/conda/lib/python3.11/site-packages/gspread/utils.py:168, in finditem(func, seq)
#     167 """Finds and returns first item in iterable for which func(item) is True."""
# --> 168 return next(item for item in seq if func(item))
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# SpreadsheetNotFound                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 gc.open('minhas_contas')
#
# ...
