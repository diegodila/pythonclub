# %%
import urllib3, base64, os, json
import http

# %%
USER='diegodila'
API_TOKEN='ATOKEN'
GIT_API_URL= f'https://api.github.com/users/{USER}/repos'
print(GIT_API_URL)
# Out:
# https://api.github.com/users/diegodila/repos

# %%
http = urllib3.PoolManager()

# %%
resp = http.request("GET", GIT_API_URL)

# %%
resp.data
# Out:
# b'[{"id":459302977,"node_id":"R_kgDOG2BoQQ","name":"AIEngineering","full_name":"diegodila/AIEngineering","private":false,"owner":{"login":"diegodila","id":41195752,"node_id":"MDQ6VXNlcjQxMTk1NzUy","avatar_url":"https://avatars.githubusercontent.com/u/41195752?v=4","gravatar_id":"","url":"https://api.github.com/users/diegodila","html_url":"https://github.com/diegodila","followers_url":"https://api.github.com/users/diegodila/followers","following_url":"https://api.github.com/users/diegodila/following{/other_user}","gists_url":"https://api.github.com/users/diegodila/gists{/gist_id}","starred_url":"https://api.github.com/users/diegodila/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/diegodila/subscriptions","organizations_url":"https://api.github.com/users/diegodila/orgs","repos_url":"https://api.github.com/users/diegodila/repos","events_url":"https://api.github.com/users/diegodila/events{/privacy}","received_events_url":"https://api.github.com/users/diegodila/received_events","type":"User","user_view_type":"public","site_admin":false},"html_url":"https://github.com/diegodila/AIEngineering","description":null,"fork":false,"url":"https://api.github.com/repos/diegodila/AIEngineering","forks_url":"https://api.github.com/repos/diegodila/AIEngineering/forks","keys_url":"https://api.github.com/repos/diegodila/AIEngineering/keys{/key_id}","collaborators_url":"https://api.github.com/repos/diegodila/AIEngineering/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/diegodila/AIEngineering/teams","hooks_url":"https://api.github.com/repos/diegodila/AIEngineering/hooks","issue_events_url":"https://api.github.com/repos/diegodila/AIEngineering/issues/events{/number}","events_url":"https://api.github.com/repos/diegodila/AIEngineering/events","assignees_url":"https://api.github.com/repos/diegodila/AIEngineering/assignees{/user}","branches_url":"https://api.github.com/repos/diegodila/AIEngineering/branches{/branch}","tags_url":"https://api.github.com/repos/diegodila/AIEngineering/tags","blobs_url":"https://api.github.com/repos/diegodila/AIEngineering/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/diegodila/AIEngineering/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/diegodila/AIEngineering/git/refs{/sha}","trees_url":"https://api.github.com/repos/diegodila/AIEngineering/git/trees{/sha}","statuses_url":"https://api.github.com/repos/diegodila/AIEngineering/statuses/{sha}","languages_url":"https://api.github.com/repos/diegodila/AIEngineering/languages","stargazers_url":"https://api.github.com/repos/diegodila/AIEngineering/stargazers","contributors_url":"https://api.github.com/repos/diegodila/AIEngineering/contributors","subscribers_url":"https://api.github.com/repos/diegodila/AIEngineering/subscribers","subscription_url":"https://api.github.com/repos/diegodila/AIEngineering/subscription","commits_url":"https://api.github.com/repos/diegodila/AIEngineering/commits{/sha}","git_commits_url":"https://api.github.com/repos/diegodila/AIEngineering/git/commits{/sha}","comments_url":"https://api.github.com/repos/diegodila/AIEngineering/comments{/number}","issue_comment_url":"https://api.github.com/repos/diegodila/AIEngineering/issues/comments{/number}","contents_url":"https://api.github.com/repos/diegodila/AIEngineering/contents/{+path}","compare_url":"https://api.github.com/repos/diegodila/AIEngineering/compare/{base}...{head}","merges_url":"https://api.github.com/repos/diegodila/AIEngineering/merges","archive_url":"https://api.github.com/repos/diegodila/AIEngineering/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/diegodila/AIEngineering/downloads","issues_url":"https://api.github.com/repos/diegodila/AIEngineering/issues{/number}","pulls_url":"https://api.github.com/repos/diegodila/AIEngineering/pulls{/number}","milestones_url":"https://api.github.com/repos/diegodila/AIEngineering/milestones{/number}","notifications_url":"https://api.github.com/repos/diegodila/AI ...

# %%
resp = http.request("GET", GIT_API_URL)
resp1  = http.request("GET", "https://httpbin.org/ip")

# %%
# print(resp.data)
type(resp.data)

# %%
json_data = json.loads(resp.data.decode('utf-8'))

# %%
repositories = [i['html_url'] for i in json_data]

# %%
os.system(''' mkdir diegao ''')
os.chdir("./diegao")
for i in repositories:
    os.system(f'git clone {i}')

# %%
list(filter(lambda d: d.keys == 'id' , a))

# %%
list(filter(lambda person: person['name'], json_data))

# %%
dict_you_want = { 'name': b[name] for name in b.keys }

# %%
for key, value in b.items():
    if(key == 'name'):
        print(value)
