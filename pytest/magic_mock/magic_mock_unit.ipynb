# %%
from unittest.mock import MagicMock

# %%
mock_obj = MagicMock()

# %%
mock_obj.metodo.return_value = 42

# %%
print(len(mock_obj))
# Out:
# 0

# %%
mock_obj.metodo()
# Out:
# 42

# %%
mock_obj.metodo.assert_called_once()

# %%
from unittest.mock import Mock

# Creating a Mock object
mock = Mock()

# Setting a return value for a method
mock.some_method.return_value = 'Hello, World!'

# Calling the method
result = mock.some_method()

# Asserting the method was called
assert mock.some_method.called
assert result == 'Hello, World!'

# %%
assert mock.some_method.called

# %%
assert result == 'Hello, World!'

# %%
assert 1 == 1

# %%
mock_fe_client = MagicMock(name='fe_client')

# %%
mock_fe_client.get_feature_table('minha_tabela')
# Out:
# <MagicMock name='fe_client.get_feature_table()' id='133957780259216'>

# %%
type(mock_fe_client.get_feature_table.assert_called_once_with(
    "minha_tabela"
))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 type(mock_fe_client.get_feature_table.assert_called_once_with(
#       2     "minha_tabela"
#       3 ))
#
# File /opt/conda/lib/python3.11/unittest/mock.py:950, in NonCallableMock.assert_called_once_with(self, *args, **kwargs)
#     945 if not self.call_count == 1:
#     946     msg = ("Expected '%s' to be called once. Called %s times.%s"
#     947            % (self._mock_name or 'mock',
#     948               self.call_count,
#     949               self._calls_repr()))
# --> 950     raise AssertionError(msg)
#     951 return self.assert_called_with(*args, **kwargs)
#
# AssertionError: Expected 'get_feature_table' to be called once. Called 0 times.

# %%
mock_fe_client
# Out:
# <MagicMock name='fe_client' id='133957780257680'>

# %%
from unittest.mock import MagicMock

mock_obj = MagicMock()

mock_obj.soma.return_value = 10

resultado = mock_obj.soma(5,5)
print(resultado)

mock_obj.soma(5,10)
# Out:
# 10
# 10

# %%
# Out:
# 10
