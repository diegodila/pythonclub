# %%
import urllib3, base64, os, json

# %%
USER='diegodila'
API_TOKEN='ATOKEN'
GIT_API_URL= f'https://api.github.com/users/{USER}/repos'
print(GIT_API_URL)
# Out:
# https://api.github.com/users/diegodila/repos

# %%
http = urllib3.PoolManager()

# %%
resp = http.request("GET", GIT_API_URL)
resp1  = http.request("GET", "https://httpbin.org/ip")

# %%
# print(resp.data)
type(resp.data)
# Out:
# bytes

# %%
json_data = json.loads(resp.data.decode('utf-8'))

# %%
repositories = [i['html_url'] for i in json_data]

# %%
os.system(''' mkdir diegao ''')
os.chdir("./diegao")
for i in repositories:
    os.system(f'git clone {i}')
# Out:
# Cloning into 'android'...
# Cloning into 'cloudplatform'...
# Cloning into 'Coursera'...
# Cloning into 'database'...
# Cloning into 'datastructure'...
# Cloning into 'design'...
# Cloning into 'diegodila'...
# Cloning into 'fiap'...
# Cloning into 'flutter'...
# Cloning into 'git'...
# Cloning into 'governance'...
# Cloning into 'java'...
# Cloning into 'javaclub'...
# Cloning into 'Javascript'...
# Cloning into 'kotlin'...
# Cloning into 'linux'...
# Cloning into 'linuxscriptsdistro'...
# Cloning into 'nodejs'...
# Cloning into 'pyspark'...
# Cloning into 'pythonclub'...
# Cloning into 'spark'...
# Cloning into 'springboot'...
# Cloning into 'webscraping'...

# %%
list(filter(lambda d: d.keys == 'id' , a))
# Out:
# []

# %%
list(filter(lambda person: person['name'], json_data))
# Out:
# [{'id': 393860806,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTM4NjA4MDY=',
#   'name': 'android',
#   'full_name': 'diegodila/android',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/android',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/android',
#   'forks_url': 'https://api.github.com/repos/diegodila/android/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/android/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/android/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/android/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/android/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/android/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/android/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/android/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/android/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/android/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/android/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/android/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/android/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/android/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/android/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/android/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/android/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/android/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/android/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/android/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/android/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/android/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/android/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/android/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/android/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/android/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/android/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/android/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/android/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/android/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/android/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/android/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/android/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/android/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/android/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/android/deployments',
#   'created_at': '2021-08-08T04:53:23Z',
#   'updated_at': '2021-12-08T17:38:57Z',
#   'pushed_at': '2021-12-08T17:38:54Z',
#   'git_url': 'git://github.com/diegodila/android.git',
#   'ssh_url': 'git@github.com:diegodila/android.git',
#   'clone_url': 'https://github.com/diegodila/android.git',
#   'svn_url': 'https://github.com/diegodila/android',
#   'homepage': None,
#   'size': 30661,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Kotlin',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 341594529,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNDE1OTQ1Mjk=',
#   'name': 'cloudplatform',
#   'full_name': 'diegodila/cloudplatform',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/cloudplatform',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/cloudplatform',
#   'forks_url': 'https://api.github.com/repos/diegodila/cloudplatform/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/cloudplatform/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/cloudplatform/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/cloudplatform/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/cloudplatform/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/cloudplatform/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/cloudplatform/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/cloudplatform/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/cloudplatform/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/cloudplatform/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/cloudplatform/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/cloudplatform/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/cloudplatform/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/cloudplatform/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/cloudplatform/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/cloudplatform/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/cloudplatform/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/cloudplatform/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/cloudplatform/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/cloudplatform/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/cloudplatform/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/cloudplatform/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/cloudplatform/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/cloudplatform/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/cloudplatform/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/cloudplatform/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/cloudplatform/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/cloudplatform/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/cloudplatform/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/cloudplatform/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/cloudplatform/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/cloudplatform/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/cloudplatform/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/cloudplatform/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/cloudplatform/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/cloudplatform/deployments',
#   'created_at': '2021-02-23T15:11:38Z',
#   'updated_at': '2021-02-23T15:15:21Z',
#   'pushed_at': '2021-08-06T04:26:32Z',
#   'git_url': 'git://github.com/diegodila/cloudplatform.git',
#   'ssh_url': 'git@github.com:diegodila/cloudplatform.git',
#   'clone_url': 'https://github.com/diegodila/cloudplatform.git',
#   'svn_url': 'https://github.com/diegodila/cloudplatform',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 198473940,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTg0NzM5NDA=',
#   'name': 'Coursera',
#   'full_name': 'diegodila/Coursera',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/Coursera',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/Coursera',
#   'forks_url': 'https://api.github.com/repos/diegodila/Coursera/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/Coursera/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/Coursera/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/Coursera/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/Coursera/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/Coursera/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/Coursera/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/Coursera/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/Coursera/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/Coursera/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/Coursera/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/Coursera/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/Coursera/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/Coursera/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/Coursera/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/Coursera/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/Coursera/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/Coursera/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/Coursera/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/Coursera/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/Coursera/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/Coursera/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/Coursera/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/Coursera/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/Coursera/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/Coursera/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/Coursera/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/Coursera/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/Coursera/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/Coursera/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/Coursera/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/Coursera/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/Coursera/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/Coursera/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/Coursera/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/Coursera/deployments',
#   'created_at': '2019-07-23T17:01:35Z',
#   'updated_at': '2020-05-19T01:13:33Z',
#   'pushed_at': '2020-05-19T01:13:31Z',
#   'git_url': 'git://github.com/diegodila/Coursera.git',
#   'ssh_url': 'git@github.com:diegodila/Coursera.git',
#   'clone_url': 'https://github.com/diegodila/Coursera.git',
#   'svn_url': 'https://github.com/diegodila/Coursera',
#   'homepage': None,
#   'size': 22,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 348490948,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNDg0OTA5NDg=',
#   'name': 'database',
#   'full_name': 'diegodila/database',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/database',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/database',
#   'forks_url': 'https://api.github.com/repos/diegodila/database/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/database/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/database/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/database/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/database/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/database/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/database/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/database/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/database/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/database/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/database/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/database/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/database/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/database/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/database/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/database/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/database/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/database/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/database/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/database/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/database/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/database/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/database/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/database/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/database/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/database/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/database/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/database/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/database/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/database/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/database/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/database/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/database/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/database/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/database/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/database/deployments',
#   'created_at': '2021-03-16T21:03:01Z',
#   'updated_at': '2021-08-10T03:25:46Z',
#   'pushed_at': '2021-08-10T03:25:43Z',
#   'git_url': 'git://github.com/diegodila/database.git',
#   'ssh_url': 'git@github.com:diegodila/database.git',
#   'clone_url': 'https://github.com/diegodila/database.git',
#   'svn_url': 'https://github.com/diegodila/database',
#   'homepage': None,
#   'size': 32,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'PLSQL',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 290954315,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTA5NTQzMTU=',
#   'name': 'datastructure',
#   'full_name': 'diegodila/datastructure',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/datastructure',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/datastructure',
#   'forks_url': 'https://api.github.com/repos/diegodila/datastructure/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/datastructure/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/datastructure/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/datastructure/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/datastructure/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/datastructure/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/datastructure/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/datastructure/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/datastructure/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/datastructure/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/datastructure/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/datastructure/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/datastructure/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/datastructure/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/datastructure/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/datastructure/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/datastructure/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/datastructure/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/datastructure/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/datastructure/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/datastructure/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/datastructure/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/datastructure/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/datastructure/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/datastructure/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/datastructure/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/datastructure/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/datastructure/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/datastructure/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/datastructure/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/datastructure/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/datastructure/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/datastructure/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/datastructure/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/datastructure/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/datastructure/deployments',
#   'created_at': '2020-08-28T04:55:14Z',
#   'updated_at': '2022-01-05T03:57:26Z',
#   'pushed_at': '2022-01-05T03:57:23Z',
#   'git_url': 'git://github.com/diegodila/datastructure.git',
#   'ssh_url': 'git@github.com:diegodila/datastructure.git',
#   'clone_url': 'https://github.com/diegodila/datastructure.git',
#   'svn_url': 'https://github.com/diegodila/datastructure',
#   'homepage': None,
#   'size': 275,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'dev'},
#  {'id': 442553688,
#   'node_id': 'R_kgDOGmDVWA',
#   'name': 'design',
#   'full_name': 'diegodila/design',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/design',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/design',
#   'forks_url': 'https://api.github.com/repos/diegodila/design/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/design/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/design/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/design/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/design/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/design/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/design/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/design/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/design/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/design/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/design/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/design/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/design/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/design/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/design/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/design/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/design/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/design/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/design/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/design/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/design/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/design/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/design/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/design/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/design/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/design/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/design/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/design/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/design/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/design/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/design/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/design/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/design/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/design/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/design/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/design/deployments',
#   'created_at': '2021-12-28T18:41:56Z',
#   'updated_at': '2021-12-30T04:32:21Z',
#   'pushed_at': '2021-12-30T04:32:18Z',
#   'git_url': 'git://github.com/diegodila/design.git',
#   'ssh_url': 'git@github.com:diegodila/design.git',
#   'clone_url': 'https://github.com/diegodila/design.git',
#   'svn_url': 'https://github.com/diegodila/design',
#   'homepage': None,
#   'size': 132,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 442326997,
#   'node_id': 'R_kgDOGl1f1Q',
#   'name': 'diegodila',
#   'full_name': 'diegodila/diegodila',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/diegodila',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/diegodila',
#   'forks_url': 'https://api.github.com/repos/diegodila/diegodila/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/diegodila/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/diegodila/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/diegodila/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/diegodila/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/diegodila/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/diegodila/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/diegodila/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/diegodila/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/diegodila/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/diegodila/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/diegodila/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/diegodila/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/diegodila/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/diegodila/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/diegodila/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/diegodila/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/diegodila/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/diegodila/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/diegodila/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/diegodila/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/diegodila/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/diegodila/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/diegodila/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/diegodila/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/diegodila/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/diegodila/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/diegodila/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/diegodila/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/diegodila/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/diegodila/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/diegodila/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/diegodila/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/diegodila/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/diegodila/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/diegodila/deployments',
#   'created_at': '2021-12-28T02:27:52Z',
#   'updated_at': '2021-12-28T03:58:27Z',
#   'pushed_at': '2021-12-28T03:58:24Z',
#   'git_url': 'git://github.com/diegodila/diegodila.git',
#   'ssh_url': 'git@github.com:diegodila/diegodila.git',
#   'clone_url': 'https://github.com/diegodila/diegodila.git',
#   'svn_url': 'https://github.com/diegodila/diegodila',
#   'homepage': None,
#   'size': 3,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 348454037,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNDg0NTQwMzc=',
#   'name': 'fiap',
#   'full_name': 'diegodila/fiap',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/fiap',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/fiap',
#   'forks_url': 'https://api.github.com/repos/diegodila/fiap/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/fiap/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/fiap/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/fiap/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/fiap/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/fiap/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/fiap/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/fiap/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/fiap/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/fiap/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/fiap/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/fiap/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/fiap/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/fiap/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/fiap/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/fiap/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/fiap/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/fiap/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/fiap/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/fiap/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/fiap/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/fiap/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/fiap/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/fiap/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/fiap/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/fiap/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/fiap/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/fiap/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/fiap/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/fiap/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/fiap/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/fiap/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/fiap/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/fiap/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/fiap/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/fiap/deployments',
#   'created_at': '2021-03-16T18:34:43Z',
#   'updated_at': '2021-09-28T00:46:27Z',
#   'pushed_at': '2021-09-28T00:46:24Z',
#   'git_url': 'git://github.com/diegodila/fiap.git',
#   'ssh_url': 'git@github.com:diegodila/fiap.git',
#   'clone_url': 'https://github.com/diegodila/fiap.git',
#   'svn_url': 'https://github.com/diegodila/fiap',
#   'homepage': None,
#   'size': 111,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 363319124,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNjMzMTkxMjQ=',
#   'name': 'flutter',
#   'full_name': 'diegodila/flutter',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/flutter',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/flutter',
#   'forks_url': 'https://api.github.com/repos/diegodila/flutter/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/flutter/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/flutter/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/flutter/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/flutter/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/flutter/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/flutter/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/flutter/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/flutter/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/flutter/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/flutter/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/flutter/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/flutter/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/flutter/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/flutter/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/flutter/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/flutter/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/flutter/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/flutter/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/flutter/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/flutter/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/flutter/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/flutter/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/flutter/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/flutter/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/flutter/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/flutter/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/flutter/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/flutter/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/flutter/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/flutter/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/flutter/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/flutter/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/flutter/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/flutter/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/flutter/deployments',
#   'created_at': '2021-05-01T04:07:21Z',
#   'updated_at': '2021-10-21T23:23:44Z',
#   'pushed_at': '2021-10-21T23:23:42Z',
#   'git_url': 'git://github.com/diegodila/flutter.git',
#   'ssh_url': 'git@github.com:diegodila/flutter.git',
#   'clone_url': 'https://github.com/diegodila/flutter.git',
#   'svn_url': 'https://github.com/diegodila/flutter',
#   'homepage': None,
#   'size': 3499,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Dart',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 375459399,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNzU0NTkzOTk=',
#   'name': 'git',
#   'full_name': 'diegodila/git',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
# ...
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'dev'},
#  {'id': 255614479,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTU2MTQ0Nzk=',
#   'name': 'spark',
#   'full_name': 'diegodila/spark',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/spark',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/spark',
#   'forks_url': 'https://api.github.com/repos/diegodila/spark/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/spark/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/spark/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/spark/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/spark/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/spark/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/spark/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/spark/deployments',
#   'created_at': '2020-04-14T13:18:20Z',
#   'updated_at': '2020-05-08T13:37:25Z',
#   'pushed_at': '2020-06-06T20:02:47Z',
#   'git_url': 'git://github.com/diegodila/spark.git',
#   'ssh_url': 'git@github.com:diegodila/spark.git',
#   'clone_url': 'https://github.com/diegodila/spark.git',
#   'svn_url': 'https://github.com/diegodila/spark',
#   'homepage': None,
#   'size': 160442,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'dev'},
#  {'id': 358595944,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNTg1OTU5NDQ=',
#   'name': 'springboot',
#   'full_name': 'diegodila/springboot',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/springboot',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/springboot',
#   'forks_url': 'https://api.github.com/repos/diegodila/springboot/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/springboot/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/springboot/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/springboot/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/springboot/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/springboot/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/springboot/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/springboot/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/springboot/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/springboot/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/springboot/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/springboot/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/springboot/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/springboot/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/springboot/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/springboot/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/springboot/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/springboot/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/springboot/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/springboot/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/springboot/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/springboot/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/springboot/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/springboot/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/springboot/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/springboot/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/springboot/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/springboot/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/springboot/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/springboot/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/springboot/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/springboot/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/springboot/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/springboot/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/springboot/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/springboot/deployments',
#   'created_at': '2021-04-16T12:43:13Z',
#   'updated_at': '2021-08-13T17:28:19Z',
#   'pushed_at': '2021-08-13T17:28:16Z',
#   'git_url': 'git://github.com/diegodila/springboot.git',
#   'ssh_url': 'git@github.com:diegodila/springboot.git',
#   'clone_url': 'https://github.com/diegodila/springboot.git',
#   'svn_url': 'https://github.com/diegodila/springboot',
#   'homepage': None,
#   'size': 1167,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'CSS',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 358288293,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNTgyODgyOTM=',
#   'name': 'webscraping',
#   'full_name': 'diegodila/webscraping',
#   'private': False,
#   'owner': {'login': 'diegodila',
#    'id': 41195752,
#    'node_id': 'MDQ6VXNlcjQxMTk1NzUy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41195752?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegodila',
#    'html_url': 'https://github.com/diegodila',
#    'followers_url': 'https://api.github.com/users/diegodila/followers',
#    'following_url': 'https://api.github.com/users/diegodila/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/diegodila/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/diegodila/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/diegodila/subscriptions',
#    'organizations_url': 'https://api.github.com/users/diegodila/orgs',
#    'repos_url': 'https://api.github.com/users/diegodila/repos',
#    'events_url': 'https://api.github.com/users/diegodila/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/diegodila/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/diegodila/webscraping',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/diegodila/webscraping',
#   'forks_url': 'https://api.github.com/repos/diegodila/webscraping/forks',
#   'keys_url': 'https://api.github.com/repos/diegodila/webscraping/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/diegodila/webscraping/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/diegodila/webscraping/teams',
#   'hooks_url': 'https://api.github.com/repos/diegodila/webscraping/hooks',
#   'issue_events_url': 'https://api.github.com/repos/diegodila/webscraping/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/diegodila/webscraping/events',
#   'assignees_url': 'https://api.github.com/repos/diegodila/webscraping/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/diegodila/webscraping/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/diegodila/webscraping/tags',
#   'blobs_url': 'https://api.github.com/repos/diegodila/webscraping/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/diegodila/webscraping/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/diegodila/webscraping/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/diegodila/webscraping/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/diegodila/webscraping/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/diegodila/webscraping/languages',
#   'stargazers_url': 'https://api.github.com/repos/diegodila/webscraping/stargazers',
#   'contributors_url': 'https://api.github.com/repos/diegodila/webscraping/contributors',
#   'subscribers_url': 'https://api.github.com/repos/diegodila/webscraping/subscribers',
#   'subscription_url': 'https://api.github.com/repos/diegodila/webscraping/subscription',
#   'commits_url': 'https://api.github.com/repos/diegodila/webscraping/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/diegodila/webscraping/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/diegodila/webscraping/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/diegodila/webscraping/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/diegodila/webscraping/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/diegodila/webscraping/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/diegodila/webscraping/merges',
#   'archive_url': 'https://api.github.com/repos/diegodila/webscraping/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/diegodila/webscraping/downloads',
#   'issues_url': 'https://api.github.com/repos/diegodila/webscraping/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/diegodila/webscraping/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/diegodila/webscraping/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/diegodila/webscraping/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/diegodila/webscraping/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/diegodila/webscraping/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/diegodila/webscraping/deployments',
#   'created_at': '2021-04-15T14:27:19Z',
#   'updated_at': '2021-05-25T00:34:32Z',
#   'pushed_at': '2021-05-25T00:34:30Z',
#   'git_url': 'git://github.com/diegodila/webscraping.git',
#   'ssh_url': 'git@github.com:diegodila/webscraping.git',
#   'clone_url': 'https://github.com/diegodila/webscraping.git',
#   'svn_url': 'https://github.com/diegodila/webscraping',
#   'homepage': None,
#   'size': 3647,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'}]

# %%
a
# Out:
# []

# %%
dict_you_want = { 'name': b[name] for name in b.keys }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_19570/2972809110.py in <module>
# ----> 1 dict_you_want = { 'name': b[name] for name in b.keys }
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
for key, value in b.items():
    if(key == 'name'):
        print(value)
# Out:
# android
