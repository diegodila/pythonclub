# %%
import requests

# %%
#ele roda com o kernel do host, se for o kernel do container jupyter nao rodará pois a porta precisa estar exposta em 3002
url = 'http://localhost:3002'

# %%
response = requests.get(url).headers

# %%
response

# %%
requests.get(url).text
